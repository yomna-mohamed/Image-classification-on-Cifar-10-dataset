# %%
# !pip install tensorflow

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
#import tensorflow as tf
from tensorflow.keras.datasets import cifar10

# %%
# Out:
# ...
# 170508288/170498071 [==============================] - 4s 0us/step

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
X_train.shape, y_train.shape,X_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
y_train=y_train.reshape(-1,)
y_test=y_test.reshape(-1,)
y_train
# Out:
# array([6, 9, 9, ..., 9, 1, 1], dtype=uint8)

# %%
plt.imshow(X_train[4])

# %% [markdown]
# # Normalized data

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# # **KNN**

# %%
import numpy as np
import pickle
import os
#from settings import PROJECT_ROOT
import sys
import platform
class NearestNeighbor(object):
  def __init__(self):
    pass

  def train(self, X, y):
    """ X is N x D where each row is an example. Y is 1-dimension of size N """
    # the nearest neighbor classifier simply remembers all the training data
    self.Xtr = X
    self.ytr = y

  def predict(self, X):
    """ X is N x D where each row is an example we wish to predict label for """
    num_test = X.shape[0]

    print(num_test)
    # lets make sure that the output type matches the input type
    Ypred = np.zeros(num_test, dtype = self.ytr.dtype)
    xrange=range
    # loop over all test rows
    for i in xrange(num_test):
      print(i)
      # find the nearest training image to the i'th test image
      # using the L1 distance (sum of absolute value differences)
      distances = np.sum(np.abs(self.Xtr - X[i,:]), axis = 1)
      min_index = np.argmin(distances) # get the index with smallest distance
      Ypred[i] = self.ytr[min_index] # predict the label of the nearest example
    return Ypred  
def load_pickle(f):
    version = platform.python_version_tuple()
    if version[0] == '2':
        return  pickle.load(f)
    elif version[0] == '3':
        return  pickle.load(f, encoding='latin1')
    raise ValueError("invalid python version: {}".format(version))



def load_CIFAR10():
    return X_train,y_train,X_test,y_test



Xtr, Ytr, Xte, Yte = load_CIFAR10() # a magic function we provide
# flatten out all images to be one-dimensional
Xtr_rows = Xtr.reshape(Xtr.shape[0], 32 * 32 * 3) # Xtr_rows becomes 50000 x 3072
Xte_rows = Xte.reshape(Xte.shape[0], 32 * 32 * 3) # Xte_rows becomes 10000 x 3072

nn = NearestNeighbor() # create a Nearest Neighbor classifier class
nn.train(Xtr_rows, Ytr) # train the classifier on the training images and labels
Yte_predict = nn.predict(Xte_rows) # predict labels on the test images
# and now print the classification accuracy, which is the average number
# of examples that are correctly predicted (i.e. label matches)
print ('accuracy: %f' % ( np.mean(Yte_predict == Yte) ))
# Out:
# Streaming output truncated to the last 5000 lines.
# 5001
# 5002
# 5003
# 5004
# 5005
# 5006
# 5007
# 5008
# 5009
# 5010
# 5011
# 5012
# 5013
# 5014
# 5015
# 5016
# 5017
# 5018
# 5019
# 5020
# 5021
# 5022
# 5023
# 5024
# 5025
# 5026
# 5027
# 5028
# 5029
# 5030
# 5031
# 5032
# 5033
# 5034
# 5035
# 5036
# 5037
# 5038
# 5039
# 5040
# 5041
# 5042
# 5043
# 5044
# 5045
# 5046
# 5047
# 5048
# 5049
# 5050
# 5051
# 5052
# 5053
# 5054
# 5055
# 5056
# 5057
# 5058
# 5059
# 5060
# 5061
# 5062
# 5063
# 5064
# 5065
# 5066
# 5067
# 5068
# 5069
# 5070
# 5071
# 5072
# 5073
# 5074
# 5075
# 5076
# 5077
# 5078
# 5079
# 5080
# 5081
# 5082
# 5083
# 5084
# 5085
# 5086
# 5087
# 5088
# 5089
# 5090
# 5091
# 5092
# 5093
# 5094
# 5095
# 5096
# 5097
# 5098
# 5099
# 5100
# 5101
# 5102
# 5103
# 5104
# 5105
# 5106
# 5107
# 5108
# 5109
# 5110
# 5111
# 5112
# 5113
# 5114
# 5115
# 5116
# 5117
# 5118
# 5119
# 5120
# 5121
# 5122
# 5123
# 5124
# 5125
# 5126
# 5127
# 5128
# 5129
# 5130
# 5131
# 5132
# 5133
# 5134
# 5135
# ...

# %%
def draw_conf_matrix(y_test,y_pred_class):
  cm = confusion_matrix(y_test, y_pred_class)
  import seaborn as sns
  sns.heatmap(cm, annot = True)
  return y_pred_class

# %%
draw_conf_matrix(y_test,Yte_predict)

# %%
def calc_classification_report(y_test,y_pred_class):
  
  from sklearn.metrics import classification_report
  mat=classification_report(y_test, y_pred_class)
  print(mat)

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# # **OVR**

# %%
# !pip install mlxtend

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mlxtend
from sklearn.preprocessing import LabelEncoder
from mlxtend.plotting import plot_decision_regions
from seaborn import load_dataset, pairplot
from sklearn.linear_model import Perceptron
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, accuracy_score, confusion_matrix
from mlxtend.plotting import category_scatter
from sklearn import svm
from sklearn.datasets import make_classification, make_circles
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler    
from matplotlib.colors import ListedColormap  
from mlxtend.plotting import plot_confusion_matrix
from sklearn.preprocessing import MultiLabelBinarizer

# %matplotlib inline

# %%
mlb = MultiLabelBinarizer()
yb_train =y_train
yb_test = y_test

# %%
print(y_train)
# Out:
# [6 9 9 ... 9 1 1]

# %%
yb1_train = np.where(y_train == 0, 1, 0)
yb2_train = np.where(y_train == 1, 1, 0)
yb3_train = np.where(y_train == 2, 1, 0)
yb4_train = np.where(y_train == 3, 1, 0)
yb5_train = np.where(y_train == 4, 1, 0)
yb6_train = np.where(y_train == 5, 1, 0)
yb7_train = np.where(y_train == 6, 1, 0)
yb8_train = np.where(y_train == 7, 1, 0)
yb9_train = np.where(y_train == 8 ,1, 0)
yb10_train =np.where(y_train == 9, 1, 0)


yb1_test = np.where(y_test == 0, 1, 0)
yb2_test = np.where(y_test == 1, 1, 0)
yb3_test = np.where(y_test == 2, 1, 0)
yb4_test = np.where(y_test == 3, 1, 0)
yb5_test = np.where(y_test == 4, 1, 0)
yb6_test = np.where(y_test == 5, 1, 0)
yb7_test = np.where(y_test == 6, 1, 0)
yb8_test = np.where(y_test == 7, 1, 0)
yb9_test = np.where(y_test == 8 ,1, 0)
yb10_test =np.where(y_test == 9, 1, 0)

# %%
def getAccuracy(model, x, y):
  return model.score(x,y)*100

# %%
def confusion_matrix_binary_classes(y_test,y_pred):
  print(confusion_matrix(y_test, y_pred))
  ax = sns.heatmap(confusion_matrix(y_test,y_pred ), annot=True, cmap='PuBuGn')
  plt.xlabel('Predictions', fontsize=18)
  plt.ylabel('Actuals', fontsize=18)
  plt.title('SVM Confusion Matrix', fontsize=18)
  plt.show()
  print(classification_report(y_test,y_pred))

# %%
def plot_binary_clasifier(X_,y,model):
  if isinstance(X_, pd.DataFrame):
    X = X_.to_numpy()
  else:
    X=X_
  plt.scatter(X[y == 0,0], X[y == 0,1], c='r', marker='o', label=0)
  plt.scatter(X[y == 1,0], X[y == 1,1], c='b', marker='^', label=1)

  x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
  y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
  xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

  z = model.predict(np.c_[xx.ravel(), yy.ravel()])
  Z= z.reshape(xx.shape)
  plt.contourf(xx, yy, Z, alpha=0.5)
  plt.xlabel('PEG')
  plt.ylabel('LPR')
  plt.title('SVM Decision Surface')
  plt.legend()
  plt.show()

# %%
print((X_train.shape))
print((y_train.shape))
print((X_test.shape))
print((yb1_train.shape))
# Out:
# (50000, 32, 32, 3)
# (50000,)
# (10000, 32, 32, 3)
# (50000,)

# %%
X_test=X_test.reshape((-1,3072))
X_train=X_train.reshape((-1,3072))

# %%
print((X_train.shape))
print((y_train.shape))
print((X_test.shape))
print((yb1_train.shape))
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (50000,)

# %% [markdown]
# **Model1**

# %%
from sklearn import linear_model
clf_1 = linear_model.LogisticRegression()
clf_1.fit(X_train, yb1_train)
y1_pred = clf_1.predict(X_test)
print('Accuracy of clf_1: {:.2f}%'.format(getAccuracy(clf_1, X_test, yb1_test)))
y1_pred_proba = clf_1.predict_proba(X_test)[:,1].reshape(-1,1)
print('\nConfusion Matrix OVR:\n')
confusion_matrix_binary_classes(yb1_test, y1_pred)
#plot_binary_clasifier(X_test,yb1_test,clf_1)
# Out:
# C:\Users\mm\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of clf_1: 90.02%
#
# Confusion Matrix OVR:
#
# [[8810  190]
#  [ 808  192]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      9000
#            1       0.50      0.19      0.28      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.71      0.59      0.61     10000
# weighted avg       0.87      0.90      0.88     10000

# %% [markdown]
# **Model 2**

# %%
from sklearn import linear_model
clf_2 = linear_model.LogisticRegression()
clf_2.fit(X_train, yb2_train)
y2_pred = clf_1.predict(X_test)
print('Accuracy of clf_2: {:.2f}%'.format(getAccuracy(clf_2, X_test, yb2_test)))
y2_pred_proba = clf_2.predict_proba(X_test)[:,1].reshape(-1,1)
print('\nConfusion Matrix OVR:\n')
confusion_matrix_binary_classes(yb2_test, y2_pred)
#plot_binary_clasifier(X_test,yb2_test,clf_2)
# Out:
# C:\Users\mm\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of clf_2: 91.06%
#
# Confusion Matrix OVR:
#
# [[8643  357]
#  [ 975   25]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93      9000
#            1       0.07      0.03      0.04      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.48      0.49      0.48     10000
# weighted avg       0.82      0.87      0.84     10000

# %% [markdown]
# **Model 3**

# %%
clf_3 = linear_model.LogisticRegression()
clf_3.fit(X_train, yb3_train)
y3_pred = clf_3.predict(X_test)
print('Accuracy of clf_3: {:.2f}%'.format(getAccuracy(clf_3, X_test, yb3_test)))
y3_pred_proba = clf_3.predict_proba(X_test)[:,1].reshape(-1,1)
print('\nConfusion Matrix OVR:\n')
confusion_matrix_binary_classes(yb3_test,y3_pred)
#plot_binary_clasifier(X_test,yb3_test,clf_3)
# Out:
# C:\Users\mm\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of clf_3: 89.50%
#
# Confusion Matrix OVR:
#
# [[8891  109]
#  [ 941   59]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      9000
#            1       0.35      0.06      0.10      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.63      0.52      0.52     10000
# weighted avg       0.85      0.90      0.86     10000

# %% [markdown]
# **Model 4**

# %%
clf_4 = linear_model.LogisticRegression()
clf_4.fit(X_train, yb4_train)
y4_pred = clf_4.predict(X_test)
print('Accuracy of clf_4: {:.2f}%'.format(getAccuracy(clf_4, X_test, yb4_test)))
y4_pred_proba = clf_4.predict_proba(X_test)[:,1].reshape(-1,1)
print('\nConfusion Matrix OVR:\n')
confusion_matrix_binary_classes(yb4_test,y4_pred)
#plot_binary_clasifier(X_test,yb4_test,clf_4)
# Out:
# C:\Users\mm\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of clf_4: 89.72%
#
# Confusion Matrix OVR:
#
# [[8921   79]
#  [ 949   51]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.95      9000
#            1       0.39      0.05      0.09      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.65      0.52      0.52     10000
# weighted avg       0.85      0.90      0.86     10000

# %%
clf_5 = linear_model.LogisticRegression()
clf_5.fit(X_train, yb5_train)
y5_pred = clf_5.predict(X_test)
print('Accuracy of clf_5: {:.2f}%'.format(getAccuracy(clf_5, X_test, yb5_test)))
y5_pred_proba = clf_5.predict_proba(X_test)[:,1].reshape(-1,1)
print('\nConfusion Matrix OVR:\n')
confusion_matrix_binary_classes(yb5_test,y5_pred)
#plot_binary_clasifier(X_test,yb5_test,clf_5)
# Out:
# C:\Users\mm\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of clf_5: 89.71%
#
# Confusion Matrix OVR:
#
# [[8889  111]
#  [ 918   82]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      9000
#            1       0.42      0.08      0.14      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.67      0.53      0.54     10000
# weighted avg       0.86      0.90      0.86     10000

# %%
clf_6 = linear_model.LogisticRegression()
clf_6.fit(X_train, yb6_train)
y6_pred = clf_6.predict(X_test)
print('Accuracy of clf_6: {:.2f}%'.format(getAccuracy(clf_6, X_test, yb6_test)))
y6_pred_proba = clf_6.predict_proba(X_test)[:,1].reshape(-1,1)
print('\nConfusion Matrix OVR:\n')
confusion_matrix_binary_classes(yb6_test,y6_pred)
#plot_binary_clasifier(X_test,yb6_test,clf_6)
# Out:
# C:\Users\mm\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of clf_6: 89.42%
#
# Confusion Matrix OVR:
#
# [[8875  125]
#  [ 933   67]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      9000
#            1       0.35      0.07      0.11      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.63      0.53      0.53     10000
# weighted avg       0.85      0.89      0.86     10000

# %%
clf_7 = linear_model.LogisticRegression()
clf_7.fit(X_train, yb7_train)
y7_pred = clf_7.predict(X_test)
print('Accuracy of clf_7: {:.2f}%'.format(getAccuracy(clf_7, X_test, yb7_test)))
y7_pred_proba = clf_7.predict_proba(X_test)[:,1].reshape(-1,1)
print('\nConfusion Matrix OVR:\n')
confusion_matrix_binary_classes(yb7_test,y7_pred)
#plot_binary_clasifier(X_test,yb7_test,clf_7)
# Out:
# C:\Users\mm\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of clf_7: 90.29%
#
# Confusion Matrix OVR:
#
# [[8844  156]
#  [ 815  185]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      9000
#            1       0.54      0.18      0.28      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.73      0.58      0.61     10000
# weighted avg       0.88      0.90      0.88     10000

# %%
clf_8 = linear_model.LogisticRegression()
clf_8.fit(X_train, yb8_train)
y8_pred = clf_8.predict(X_test)
print('Accuracy of clf_8: {:.2f}%'.format(getAccuracy(clf_8, X_test, yb8_test)))
y8_pred_proba = clf_8.predict_proba(X_test)[:,1].reshape(-1,1)
print('\nConfusion Matrix OVR:\n')
confusion_matrix_binary_classes(yb8_test,y8_pred)
#plot_binary_clasifier(X_test,yb8_test,clf_8)
# Out:
# C:\Users\mm\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of clf_8: 90.56%
#
# Confusion Matrix OVR:
#
# [[8850  150]
#  [ 794  206]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      9000
#            1       0.58      0.21      0.30      1000
#
#     accuracy                           0.91     10000
#    macro avg       0.75      0.59      0.63     10000
# weighted avg       0.88      0.91      0.88     10000

# %%
clf_9 = linear_model.LogisticRegression()
clf_9.fit(X_train, yb9_train)
y9_pred = clf_9.predict(X_test)
print('Accuracy of clf_9: {:.2f}%'.format(getAccuracy(clf_9, X_test, yb9_test)))
y9_pred_proba = clf_9.predict_proba(X_test)[:,1].reshape(-1,1)
print('\nConfusion Matrix OVR:\n')
confusion_matrix_binary_classes(yb9_test,y9_pred)
#plot_binary_clasifier(X_test,yb9_test,clf_9)
# Out:
# C:\Users\mm\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of clf_9: 89.79%
#
# Confusion Matrix OVR:
#
# [[8735  265]
#  [ 756  244]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94      9000
#            1       0.48      0.24      0.32      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.70      0.61      0.63     10000
# weighted avg       0.88      0.90      0.88     10000

# %%
clf_10 = linear_model.LogisticRegression()
clf_10.fit(X_train, yb10_train)
y10_pred = clf_10.predict(X_test)
print('Accuracy of clf_10: {:.2f}%'.format(getAccuracy(clf_10, X_test, yb10_test)))
y10_pred_proba = clf_10.predict_proba(X_test)[:,1].reshape(-1,1)
print('\nConfusion Matrix OVR:\n')
confusion_matrix_binary_classes(yb10_test,y10_pred)
#plot_binary_clasifier(X_test,yb10_test,clf_10)
# Out:
# C:\Users\mm\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of clf_10: 90.10%
#
# Confusion Matrix OVR:
#
# [[8784  216]
#  [ 774  226]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      9000
#            1       0.51      0.23      0.31      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.72      0.60      0.63     10000
# weighted avg       0.88      0.90      0.88     10000

# %%
from sklearn.preprocessing import MultiLabelBinarizer

mlb = MultiLabelBinarizer()
mlb.fit(X_train)
yb_all = np.hstack((y1_pred_proba, y2_pred_proba, y3_pred_proba, y5_pred_proba, y6_pred_proba, y7_pred_proba, y8_pred_proba, y9_pred_proba,y10_pred_proba))
predicted_clases = mlb.classes_[np.argmax(yb_all, axis=1)]
predicted_clases
# Out:
# array([7, 8, 7, ..., 4, 4, 6], dtype=object)

# %%
y_true = y_test.squeeze().astype(int)
y_pred =  predicted_clases.squeeze().astype(int)
print(f"the final model accuracy :{accuracy_score(y_true, y_pred)*100}")
print('\nConfusion Matrix:\n')
print(confusion_matrix(y_true,y_pred ))
ax = sns.heatmap(confusion_matrix(y_true,y_pred ), annot=True, cmap='Purples')

plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Logistic Regression Confusion Matrix', fontsize=18)
plt.show()
print(classification_report(y_true,y_pred))
# Out:
# the final model accuracy :17.78
#
# Confusion Matrix:
#
# [[508  43  64  26  35  27  50 169  78   0]
#  [ 76 469  24  18  61  35  57 101 159   0]
#  [121  44 294 127 127 133  78  52  24   0]
#  [ 75  63 105  75 331 159  62  59  71   0]
#  [ 77  24 131 285 131 163 125  37  27   0]
#  [ 58  52 109  88 421 111  84  47  30   0]
#  [ 34  43  81  98 137 500  42  30  35   0]
#  [ 64  46  75  87 100  40 459  47  82   0]
#  [160  77  23  11  54  16  20 538 101   0]
#  [ 86 179  21  17  40  48  67 106 436   0]]
#               precision    recall  f1-score   support
#
#            0       0.40      0.51      0.45      1000
#            1       0.45      0.47      0.46      1000
#            2       0.32      0.29      0.31      1000
#            3       0.09      0.07      0.08      1000
#            4       0.09      0.13      0.11      1000
#            5       0.09      0.11      0.10      1000
#            6       0.04      0.04      0.04      1000
# ...

# %% [markdown]
# # **Part 3**

# %% [markdown]
# Part 3. Support Vector Machine (SVM) Classification (4 Marks)
# In Part 3. you will use Scikit-learn to perform classification, again on the Cifar10 dataset. You can use the built in SVM library for classification. As with logistic regression, SVM is designed for binary classification. However, in this case Scikit-learn will handle the OvR models behind the scenes.
#
# Your task is to compare different modes of the SVM and determine the best performer.
#
# Create an SVM baseline using the LinearSVC() function. Make sure to use the primal solution and use "ovr" for multiclass Calculate the accuracy score for comparison.
#
# Next you will explore the effect of the cost parameter on the accuracy.
#
# Run the classification with a range of C values For example: [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000 ]
# Plot the results as an accuracy vs. C-parameter curve on a logarithmic scale.
# Add a regularization term.
#
# Rerun the above experiment, but this time use L1 regularization.
# Again, plot the results as an accuracy vs. C-parameter curve on a logarithmic scale.
# For the final experiment you will use the SVC() function to run the classifer with a kernel.
#
# Use a radial basis function when training a new model
# Find the optimal combination of values for the cost and gamma parameters. Use the following values in your loop:
# for cost in [0.01, 0.1, 1, 10, 100]:
#  for gamma in [0.01, 0.1, 1, 10, 100]:
# Again, plot the results as an accuracy vs. C-parameter curve on a logarithmic scale.
# Choose the model with the highest accuracy and plot the confusion matrix. In your discussion explain the results of your experiments and the reason for increased performance from the baseline (if any). Comment on the effect of the cost-paramenter and the L1 penalty on accuracy as well as any overfitting you observed. Discuss the confusion matrix of the model accuracy and provide some reasons for high-values found off the main diagonal.
#
# Bonus Mark
# Instead of using raw pixel values compute an alternate feature representation for your dataset and re-run train the model. Compare the accuracy of the model using the new feature representation with the model trained with pixel values.

# %% [markdown]
# # **SVM**

# %% [markdown]
# # Baseline

# %% [markdown]
# Create an SVM baseline using the LinearSVC() function. Make sure to use the primal solution and use "ovr" for multiclass Calculate the accuracy score for comparison.

# %%
from sklearn import svm
clf = svm.LinearSVC()
clf.fit(X_train_new, y_train_new)
y_pred_svm=clf.predict(X_test_new)
#print(y_pred_svm)
evaluation_svm = accuracy_score(y_test_new, y_pred_svm)
confusion_matrix_binary_classes(y_test_new,y_pred_svm)
print(evaluation_svm)
# Out:
# C:\Users\mm\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [[42 26 31  7  7  4  7  7 51 14]
#  [ 5 94 20 10  8  3  9  6 17 26]
#  [23 20 65 20 18 11 13  4 16  5]
#  [ 8 42 38 37 14 19 22  2 10  7]
#  [ 7 16 65 20 41 11 16 11  7  4]
#  [13 31 40 36 10 25 10  6  9  5]
#  [ 6 25 45 30 19 12 60  6  6  7]
#  [ 7 27 35 19 24 12 10 42  9  8]
#  [18 47 20  6  6  3  4  2 97 14]
#  [18 79  7  9  8  5  9  7 24 37]]
#               precision    recall  f1-score   support
#
#            0       0.29      0.21      0.24       196
#            1       0.23      0.47      0.31       198
#            2       0.18      0.33      0.23       195
#            3       0.19      0.19      0.19       199
#            4       0.26      0.21      0.23       198
#            5       0.24      0.14      0.17       185
#            6       0.38      0.28      0.32       216
# ...

# %%
print(len(y_pred_svm))
# Out:
# 2000

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 evaluation_svm = accuracy_score(y_test, y_pred_svm)
#       2 confusion_matrix_binary_classes(y_test,y_pred_svm)
#       3 print(evaluation_svm)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:211, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     145 """Accuracy classification score.
#     146
#     147 In multilabel classification, this function computes subset accuracy:
#    (...)
#     207 0.5
#     208 """
#     210 # Compute accuracy for each possible representation
# --> 211 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212 check_consistent_length(y_true, y_pred, sample_weight)
#     213 if y_type.startswith("multilabel"):
#
# ...

# %%
X_train_new=X_train[:10000]
y_train_new=y_train[:10000]
X_test_new=X_test[:2000]
y_test_new=y_test[:2000]

# %%
print((X_train.shape))
print((y_train.shape))
print((X_test.shape))
print((y_test.shape))
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
print((X_train_new.shape))
print((y_train_new.shape))
print((X_test_new.shape))
print((y_test_new.shape))
# Out:
# (10000, 3072)
# (10000,)
# (2000, 3072)
# (2000,)

# %% [markdown]
# Run the classification with a range of C values For example: [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000 ] Plot the results as an accuracy vs. C-parameter curve on a logarithmic scale.

# %%
cost_list=[0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000 ]
from sklearn import svm
accuracy_list1=[]
for c in (cost_list):
    clf = LinearSVC(multi_class='ovr', C=c)
    clf.fit(X_train_new, y_train_new)
    y_pred_svm=clf.predict(X_test_new)
    evaluation_svm = accuracy_score(y_test_new, y_pred_svm)
    confusion_matrix_binary_classes(y_test_new,y_pred_svm)
    accuracy_list1.append(evaluation_svm)
# Out:
# [[ 78   9  10  10   3   1  17   4  50  14]
#  [ 11  49   7   8   4   2  37   5  32  43]
#  [ 38   6  37   9  14   2  63   5  13   8]
#  [ 19   6  30  34   9   7  65  10   3  16]
#  [  9   7  35  12  17   1  82  12  12  11]
#  [ 14   1  23  32  11  19  53   7  14  11]
#  [  9   3  20  10   5   2 139  14   3  11]
#  [ 14   6  26  13  24   3  34  37  13  23]
#  [ 20  11   4  11   1   5   8   4 121  32]
#  [ 12  11   5   3   6   1  23   7  28 107]]
#               precision    recall  f1-score   support
#
#            0       0.35      0.40      0.37       196
#            1       0.45      0.25      0.32       198
#            2       0.19      0.19      0.19       195
#            3       0.24      0.17      0.20       199
#            4       0.18      0.09      0.12       198
#            5       0.44      0.10      0.17       185
#            6       0.27      0.64      0.38       216
#            7       0.35      0.19      0.25       193
# ...

# %%
import matplotlib.pyplot as plt 
def draw_acc_vs_c(cost_list,accuracy_list):
    datax = cost_list
    datay = accuracy_list
 
   #convert x-axis to Logarithmic scale
    plt.xscale("log")
 
    plt.plot(datax,datay)

# %%
draw_acc_vs_c(cost_list,accuracy_list1)

# %% [markdown]
# # Add a regularization term.

# %%
from sklearn.svm import LinearSVC, SVC
accuracy_list2=[]
for c in (cost_list):
    clf = LinearSVC(multi_class='ovr',C=c,penalty="l1",dual=False)
    clf.fit(X_train_new, y_train_new)
    y_pred_svm=clf.predict(X_test_new)
    evaluation_svm = accuracy_score(y_test_new, y_pred_svm)
    confusion_matrix_binary_classes(y_test_new,y_pred_svm)
    accuracy_list2.append(evaluation_svm)
# Out:
# [[  0   0 196   0   0   0   0   0   0   0]
#  [  0   0 198   0   0   0   0   0   0   0]
#  [  0   0 195   0   0   0   0   0   0   0]
#  [  0   0 199   0   0   0   0   0   0   0]
#  [  0   0 198   0   0   0   0   0   0   0]
#  [  0   0 185   0   0   0   0   0   0   0]
#  [  0   0 216   0   0   0   0   0   0   0]
#  [  0   0 193   0   0   0   0   0   0   0]
#  [  0   0 217   0   0   0   0   0   0   0]
#  [  0   0 203   0   0   0   0   0   0   0]]
# C:\Users\mm\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# plot the results as an accuracy vs. C-parameter curve on a logarithmic scale.

# %%
draw_acc_vs_c(cost_list,accuracy_list2)

# %% [markdown]
# Find the optimal combination of values for the cost and gamma parameters. Use the following values in your loop:
# for cost in [0.01, 0.1, 1, 10, 100]:
#  for gamma in [0.01, 0.1, 1, 10, 100]:
# Again, plot the results as an accuracy vs. C-parameter curve on a logarithmic scale.

# %%
accuracy_list3=[]
gamma_list = [0.01, 0.1, 1, 10, 100]

for c in cost_list:
    for gamma in gamma_list:
       
        clf = svm.SVC(C=c,gamma=gamma)
        clf.fit(X_train_new, y_train_new)
        y_pred_svm=clf.predict(X_test_new)
        evaluation_svm = accuracy_score(y_test_new, y_pred_svm)
        confusion_matrix_binary_classes(y_test_new,y_pred_svm)
        accuracy_list3.append(evaluation_svm)

# %%
draw_acc_vs_c(cost_list,accuracy_list3)

# %% [markdown]
# # Choose the model with the highest accuracy and plot the confusion matrix.
